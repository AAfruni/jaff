# %% [markdown]
# GENERATE C++ CODE COMPATIBLE WITH MICROPHYSICS

# %%
# Create builder and generate amrexastro code
from jaff.network import Network
from jaff.builder import Builder
import os

# Load the test2 network
network = Network("../networks/GOW.dat")
builder = Builder(network)
builds_dir = builder.build(template="amrexastro")

print("\nC++ amrexastro code generated successfully!")
print(f"Generated files are located at {builds_dir}")
# Out:
# Welcome to JAFF: Just Another Fancy Format!
# Loading network from ../networks/GOW.dat
# Network label = GOW
# 100%|██████████| 51/51 [00:00<00:00, 304.13it/s]
# Variables found: ['av', 'c', 'chi', 'crate', 'd2g', 'gradv', 'tgas']
# Loaded 51 reactions
# Lodaded 0 photo-chemistry reactions
# Found the following interpolation functions:  ['alpha_CO_interp2d', 'PsiGD_coll_interp2d', 'L0_CO_interp1d', 'LLTE_CO_interp2d', 'nHalf_CO_interp2d']
# WARNING: electron recombination not found for H2+
# WARNING: duplicate reaction found: C -> C+ + e-
# All done!
# Building network with template: amrexastro
# Preprocessing /home/aafruni/GitHub_projects/jaff/src/jaff/templates/amrexastro/actual_rhs.H -> /home/aafruni/GitHub_projects/jaff/examples/actual_rhs.H
# Preprocessing /home/aafruni/GitHub_projects/jaff/src/jaff/templates/amrexastro/actual_network_data.cpp -> /home/aafruni/GitHub_projects/jaff/examples/actual_network_data.cpp
# Network built successfully using template 'amrexastro'.
# Output files are located in: /home/aafruni/GitHub_projects/jaff/examples
#
# C++ amrexastro code generated successfully!
# Generated files are located at /home/aafruni/GitHub_projects/jaff/examples
